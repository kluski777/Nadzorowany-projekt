# %% [markdown]
# # Create dataset from the github repo

# %%
import sys
import os

os.environ["COMET_API_KEY"] = "QWOxSIxgY5YQBTvC476IEIxSG"
os.environ["COMET_PROJECT_NAME"] = "unsupervised-learning"
os.environ["COMET_WORKSPACE"] = "ekipa"

# !cp -r /kaggle/input/unsupervised-learning /kaggle/working/project
# !pip install comet-ml

os.chdir('/kaggle/working/project')
sys.path.insert(0, '/kaggle/working/project')
sys.path.insert(0, '/kaggle/working/project/src')

from main import load_config
from training import train_autoencoder
config = load_config('config.yaml')
config["model"]["latent_channels"] = 64
config["training"]["max_epochs"] = 150
config["experiment"]["name"] = "autoencoder-10k-CT-Residual-mse-latent8k"
train_autoencoder(config)
# Out:
# cp: cannot stat '/kaggle/input/unsupervised-learning': No such file or directory
# Requirement already satisfied: comet-ml in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (3.53.0)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (0.24.2)
# Requirement already satisfied: everett<3.2.0,>=1.0.1 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml) (3.1.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (7.0.0)
# Requirement already satisfied: python-box<7.0.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (6.1.0)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (2.32.3)
# Requirement already satisfied: rich>=13.3.2 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (14.1.0)
# Requirement already satisfied: semantic-version>=2.8.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (3.0.0a5)
# Requirement already satisfied: setuptools in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (79.0.1)
# Requirement already satisfied: simplejson in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (3.20.2)
# Requirement already satisfied: urllib3>=1.26.8 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.2 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (1.17.3)
# Requirement already satisfied: wurlitzer>=1.0.2 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from comet-ml) (3.1.1)
# Requirement already satisfied: configobj in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml) (5.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.24.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from requests>=2.18.4->comet-ml) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from requests>=2.18.4->comet-ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from requests>=2.18.4->comet-ml) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from rich>=13.3.2->comet-ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from rich>=13.3.2->comet-ml) (2.19.1)
# Requirement already satisfied: opentelemetry-sdk>=1.4.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from sentry-sdk>=1.1.0->comet-ml) (1.36.0)
# Requirement already satisfied: mdurl~=0.1 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet-ml) (0.1.2)
# Requirement already satisfied: opentelemetry-api==1.36.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.4.0->sentry-sdk>=1.1.0->comet-ml) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.4.0->sentry-sdk>=1.1.0->comet-ml) (0.57b0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.4.0->sentry-sdk>=1.1.0->comet-ml) (4.14.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from opentelemetry-api==1.36.0->opentelemetry-sdk>=1.4.0->sentry-sdk>=1.1.0->comet-ml) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/mamusiaarusia/myenv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api==1.36.0->opentelemetry-sdk>=1.4.0->sentry-sdk>=1.1.0->comet-ml) (3.23.0)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 get_ipython().system('cp -r /kaggle/input/unsupervised-learning /kaggle/working/project')
#       9 get_ipython().system('pip install comet-ml')
# ---> 11 os.chdir('/kaggle/working/project')
#      12 sys.path.insert(0, '/kaggle/working/project')
#      13 sys.path.insert(0, '/kaggle/working/project/src')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/project'
