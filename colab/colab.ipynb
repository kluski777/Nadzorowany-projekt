# %%
import os
from google.colab import drive

# %%
# !git clone https://github.com/kluski777/Nadzorowany-projekt.git
os.chdir('/content/Nadzorowany-projekt')
# Out:
# Cloning into 'Nadzorowany-projekt'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 272 (delta 125), reused 168 (delta 77), pack-reused 54 (from 1)
# Receiving objects: 100% (272/272), 35.60 MiB | 14.39 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
# !git pull
# !git checkout feature/umap
# Out:
# Already up to date.
# Branch 'feature/umap' set up to track remote branch 'feature/umap' from 'origin'.
# Switched to a new branch 'feature/umap'

# %%
drive.mount('/content/drive');
# !cp /content/drive/MyDrive/UNN/.env /content/Nadzorowany-projekt/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install comet_ml
# !pip install pytorch_lightning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.1/775.1 kB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.2
#     Uninstalling python-box-7.3.2:
#       Successfully uninstalled python-box-7.3.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.6/831.6 kB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 69.2 MB/s eta 0:00:00
# ...

# %%
# !python ./src/main.py train_autoencoder
# Out:
# Loading configuration from: config.yaml
# Seed set to 42
#
# Model architecture:
# AutoEncoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Conv2d(64, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): GELU(approximate='none')
#     (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): GELU(approximate='none')
#     (9): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): GELU(approximate='none')
# ...
