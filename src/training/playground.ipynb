# %%
import sys
sys.path.insert(0, '/home/mamusiaarusia/pollodzka/sem2/nowy_nadzorowany/Nadzorowany-projekt/src/data')

from inpainter_module import LatentInpainterDataModule

# %%
datamodule = LatentInpainterDataModule(
    latent_dir="../../data/latent_spaces",
    cluster_id=None,  # None = use all data
    batch_size=64,
    num_workers=4,
)

datamodule.setup()
# Out:
# Loaded 8000 samples from train split (Memory Mapped)
# Loaded 1000 samples from val split (Memory Mapped)
# Loaded 1000 samples from test split (Memory Mapped)
#
# ...
# Inpainter Dataset Setup Complete:
#   Cluster ID: All
#   Training:   8000 samples
#   Validation: 1000 samples
# ...

# %%
import matplotlib.pyplot as plt
import torch

batch = datamodule.train_dataset[:32]
images = batch["image"]
masks = batch["mask"]

for img, mask in zip(images, masks):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 13))
    plt.axis('off')
    ax[0].imshow(img.T)
    ax[1].imshow(mask.T)
    plt.show()
